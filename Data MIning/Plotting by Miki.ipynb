# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
from sklearn.datasets import load_iris
data=load_iris()
df=pd.DataFrame(data=data.data,columns=data.feature_names)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
df.head(10).plot.bar()
# Out:
# <Axes: >

# %%
df.head(10).plot.bar(stacked=True)
# Out:
# <Axes: >

# %%
df.head(10)[["sepal length (cm)","sepal width (cm)"]].plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
df.plot.hist(alpha=0.72)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot.box()
# Out:
# <Axes: >

# %%
df.plot.area()
# Out:
# <Axes: >

# %%
df.plot.scatter(x="sepal length (cm)",y="sepal width (cm)" )
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
df.plot.scatter(x="sepal length (cm)",y="sepal width (cm)",s=df["petal length (cm)"]*df["petal width (cm)"], c=data['target'], colormap="viridis"  )
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
from matplotlib.colors import Colormap


df.plot.scatter(x="sepal length (cm)",y="sepal width (cm)",c=data['target'], colormap="viridis" )
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt

plt.figure()
plt=scatter_matrix(df,c=data["target"],marker='o',s=10,alpha=.8,figsize=[10,10])
plt
# Out:
# array([[<Axes: xlabel='sepal length (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='sepal length (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='sepal width (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='petal length (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='petal width (cm)'>,
# ...

# %%
pd.DataFrame(data=data.target).value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(np.sort(df["sepal length (cm)"]), np.sort(df["sepal width (cm)"]))
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
plt.show()
plt.close()

# %%
from math import dist

import matplotlib.pyplot
import scipy
import matplotlib
scipy.stats.probplot(df["sepal length (cm)"],dist="norm",plot=matplotlib.pyplot);
